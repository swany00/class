# %% [markdown]
# ![page_19.png](attachment:page_19.png)

# %%
R^2 비교할때를 말한다. 

오버피팅과 언더피팅
사이즈가 줄면 분산이 커진다 만약에 똑같은 수준의 에러가 나타나야한다고 가정할때
평가데이터와 훈련데이터의 사이즈가 작아서 평가데이터에서 에러가 작게 나타날 수도 있다.
훈련데이터세트 보다 평가데이터에서는 분산을 작게 만드는게 좋다. 그래서 평가데이터의 세트는 더 크게 만들어진다.
즉 훈련데이터세트의 크기를 크게 해야한다.
# Out:
#   Cell In[5], line 1
#     R^2 비교할때를 말한다.
#         ^
# SyntaxError: invalid syntax

# %%
교호작용 
문제의 취지 
x1,x2,x3를 모두 쓰고 x1*x2,x1*x3,x2*x3 중 어떤거를 쓸것이다.

즉 원래변수(주요효과)를 모두 포함시켜놓은 뒤에 x1*x2,x1*x3,x2*x3 중 어떤거를 쓸것이냐가 문제였다.
